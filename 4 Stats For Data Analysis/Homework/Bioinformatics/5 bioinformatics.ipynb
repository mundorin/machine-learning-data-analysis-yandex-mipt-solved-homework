# %%
import pandas as pd
import numpy as np
import scipy
from statsmodels.stats import multitest 
from statsmodels.sandbox.stats.multicomp import multipletests 

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('gene_high_throughput_sequencing.csv')
df.loc()

# %%
normal_patient = df[df.Diagnosis.values == 'normal']
early_neoplasia_patient = df[df.Diagnosis.values == 'early neoplasia']
cancer_patient = df[df.Diagnosis.values == 'cancer']

# %%
normal_neoplasia_pvalue = scipy.stats.ttest_ind(normal_patient.iloc[:,2:],early_neoplasia_patient.iloc[:,2:],equal_var=0).pvalue
cancer_neoplasia_pvalue = scipy.stats.ttest_ind(cancer_patient.iloc[:,2:],early_neoplasia_patient.iloc[:,2:],equal_var=0).pvalue

# %%
(normal_neoplasia_pvalue < 0.05).sum()
# Out:
# 1575

# %%
(cancer_neoplasia_pvalue < 0.05).sum()
# Out:
# 3490

# %%
normal_neoplasia_pvalue
# Out:
# array([6.90766016e-01, 3.17853128e-05, 6.02726639e-02, ...,
#        6.70394526e-01, 7.93924592e-01, 6.61031158e-01])

# %%
normal_neoplasia_mask = multitest.multipletests(normal_neoplasia_pvalue,alpha = 0.025,method = 'holm')[0]

# %%
cancer_neoplasia_mask = multitest.multipletests(cancer_neoplasia_pvalue,alpha = 0.025,method = 'holm')[0]

# %%
def F(c,t,mask):
    c_mean = c.mean()
    t_mean = t.mean()
    c_mask = c_mean[mask]
    t_mask = t_mean[mask]
    res = 0
    for i,j in zip(c_mask,t_mask):
        if i > j:
            if i/j > 1.5:
                res+=1
        else:
            if j/i > 1.5:
                res+=1
    return res

# %%
F(normal_patient,early_neoplasia_patient,normal_neoplasia_mask)
# Out:
# 2

# %%
F(early_neoplasia_patient,cancer_patient,cancer_neoplasia_mask)
# Out:
# 77

# %%
cols = df_normal.columns[2:].to_numpy()
get_fold_changes(early_neoplasia_patient, cancer_patient, cols, 1.5, 'holm', 0.025)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[173], line 2
#       1 cols = df_normal.columns[2:].to_numpy()
# ----> 2 get_fold_changes(early_neoplasia_patient, cancer_patient, cols, 1.5, 'holm', 0.025)
#
# Cell In[164], line 8, in get_fold_changes(df_control, df_treatment, cols, p_vals, method, alpha)
#       6 def get_fold_changes(df_control, df_treatment, cols, p_vals, method, alpha):
#       7     reject = multipletests(p_vals, alpha = alpha, method = method) [0]
# ----> 8     means_control = df_control.loc[:,cols[reject]].mean()
#       9     means_treatment = df_treatment.loc[:,cols[reject]].mean()
#      10     df_means = pd.DataFrame([means_control, means_treatment])
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 15748 but corresponding boolean dimension is 1

# %%
cols
# Out:
# array(['LOC643837', 'LOC100130417', 'SAMD11', ..., 'CYorf15B', 'KDM5D',
#        'EIF1AY'], dtype=object)

# %%
df_normal = df[df.Diagnosis == 'normal']
df_early = df[df.Diagnosis == 'early neoplasia']
df_cancer = df[df.Diagnosis == 'cancer']
cols = df_normal.columns[2:].to_numpy()

def compare_df_ttest_columns(df_control, df_treatment, cols):
    p_vals = [scipy.stats.ttest_ind(df_control[col], df_treatment[col], equal_var = False).pvalue for col in cols]
    return np.array(p_vals)

cols = df_normal.columns[2:].to_numpy()
p_vals_normal_early = compare_df_ttest_columns(df_normal, df_early, cols)
p_vals_early_cancer = compare_df_ttest_columns(df_early, df_cancer, cols)

# %%
def get_fold_change(C,T):
    if T>C:
        return T/C
    else:
        return -C/T
def get_fold_changes(df_control, df_treatment, cols, p_vals, method, alpha):
    reject = multipletests(p_vals, alpha = alpha, method = method) [0]
    means_control = df_control.loc[:,cols[reject]].mean()
    means_treatment = df_treatment.loc[:,cols[reject]].mean()
    df_means = pd.DataFrame([means_control, means_treatment])
    fold_changes = df_means.apply(lambda cols: get_fold_change(cols[0], cols[1]))
    return fold_changes
def get_practic_fold_change_count(df_control, df_treatment, cols, 
                                  p_vals, method, alpha, threshold):
    fold_changes = get_fold_changes(df_control, df_treatment, cols, p_vals, method, alpha)
    return np.sum(np.abs(fold_changes)>threshold)

# %%
alpha = 0.05 / 2
practic_fc_normal_early = get_practic_fold_change_count(df_normal, df_early, cols, 
                                                        p_vals_normal_early, 'holm', alpha, 1.5)
practic_fc_early_cancer = get_practic_fold_change_count(df_early, df_cancer, cols, 
                                                        p_vals_early_cancer, 'holm', alpha, 1.5)

print(practic_fc_normal_early,'2-1-normal_early-holm.txt')
print(practic_fc_early_cancer,'2-2-early_cancer-holm.txt')
# Out:
# 2 2-1-normal_early-holm.txt
# 77 2-2-early_cancer-holm.txt

# %%
p_vals_normal_early
# Out:
# array([6.90766016e-01, 3.17853128e-05, 6.02726639e-02, ...,
#        6.70394526e-01, 7.93924592e-01, 6.61031158e-01])

# %%
normal_neoplasia_pvalue
# Out:
# array([6.90766016e-01, 3.17853128e-05, 6.02726639e-02, ...,
#        6.70394526e-01, 7.93924592e-01, 6.61031158e-01])

# %%
early_neoplasia_patient
# Out:
#                Patient_id        Diagnosis  LOC643837  LOC100130417  \
# 24  STT5424_Breast_001_EN  early neoplasia   2.516305     11.430887
# 25  STT5431_Breast_002_EN  early neoplasia   1.937270      9.686352
# 26  STT5442_Breast_004_EN  early neoplasia   1.405858     15.119783
# 27  STT5445_Breast_005_EN  early neoplasia   2.131757      8.789458
# 28  STT5511_Breast_011_EN  early neoplasia   2.421766      7.830416
# 29  STT5426_Breast_023_EN  early neoplasia   4.668232     14.949208
# 30  STT5440_Breast_003_EN  early neoplasia   3.386331     12.379176
# 31  STT5449_Breast_006_EN  early neoplasia   1.247440      4.260819
# 32  STT5465_Breast_007_EN  early neoplasia   1.591747      8.372450
# 33  STT5476_Breast_009_EN  early neoplasia   0.979074      3.706715
# 34  STT5503_Breast_010_EN  early neoplasia   4.730638     16.458594
# 35  STT5567_Breast_012_EN  early neoplasia   0.964837      6.375715
# 36  STT5571_Breast_013_EN  early neoplasia   0.949252      7.960901
# 37  STT5574_Breast_014_EN  early neoplasia   1.068210      4.737204
# 38  STT5577_Breast_015_EN  early neoplasia   1.679849      3.617088
# 39  STT5580_Breast_016_EN  early neoplasia   0.885375      4.876263
# 40  STT5612_Breast_017_EN  early neoplasia   4.567425      6.078425
# 41  STT5616_Breast_019_EN  early neoplasia   3.060481     10.578542
# 42  STT5619_Breast_018_EN  early neoplasia   2.888731      9.084079
# 43  STT5667_Breast_020_EN  early neoplasia   1.285190      7.382856
# 44  STT5747_Breast_021_EN  early neoplasia   5.753165      6.739048
# 29   2.168022  1.132213  1.132213   1.132213  2.849339   1.132213   9.495298
# 30   6.040419  1.768454  1.768454   1.768454  1.768454   1.768454  17.889667
# 31  10.461652  1.247440  1.247440   1.247440  1.247440   1.247440  22.349725
# 32   9.506166  1.591747  1.591747   1.591747  1.591747   1.591747  18.264679
# 33   7.562780  0.979074  0.979074   0.979074  0.979074   0.979074  22.461877
# 34   5.265279  1.001020  1.001020   1.001020  1.001020   1.001020  25.813908
# 35   9.371011  0.964837  0.964837   0.964837  0.964837   0.964837  21.796202
# 36   6.461426  1.817680  0.949252   0.949252  0.949252   0.949252  19.873935
# 37   4.044178  1.068210  1.068210   1.068210  1.068210   1.068210   6.839882
# 38   3.321300  0.877273  0.877273   0.877273  0.877273   0.877273  16.729629
# 39   5.850622  0.885375  0.885375   0.885375  0.885375   0.885375  14.700061
# 40   3.580284  0.868346  0.868346   0.868346  0.868346   0.868346  17.618377
# 41   6.080559  7.529425  8.036159  10.945006  5.014157   8.964100  12.773999
# 42   7.437925  1.843833  0.962910   0.962910  0.962910   0.962910  16.444827
# 43   6.759987  9.927349  9.927349  10.778244  6.425951  10.361535  10.146765
# 44   2.909839  1.519614  3.824277   1.519614  1.519614   1.519614   7.181414
# 45   2.080363  2.080363  3.983593   2.080363  2.080363   2.080363  10.942527
# 46   4.680214  0.990351  0.990351   0.990351  0.990351   0.990351  15.459200
# 47   4.628550  1.122588  1.122588   1.122588  1.122588   1.122588  15.702866
# 48   4.146897  1.647810  1.647810   1.647810  1.647810   1.647810  13.009698
#
#     CYorf15B      KDM5D    EIF1AY
# 24  1.314098   1.314098  1.314098
# 25  1.937270   1.937270  1.937270
# 26  1.405858   1.405858  1.405858
# 27  2.131757   2.131757  2.131757
# 28  1.264726   1.264726  1.264726
# 29  1.132213   1.132213  1.132213
# 30  1.768454   1.768454  1.768454
# 31  1.247440   1.247440  1.247440
# 32  1.591747   1.591747  1.591747
# 33  0.979074   0.979074  0.979074
# 34  1.001020   1.001020  1.001020
# 35  0.964837   0.964837  0.964837
# 36  0.949252   0.949252  0.949252
# 37  1.068210   1.068210  1.068210
# 38  0.877273   0.877273  0.877273
# 39  0.885375   0.885375  0.885375
# 40  0.868346   0.868346  0.868346
# 41  4.604125  10.578542  5.014157
# 42  0.962910   0.962910  0.962910
# 43  9.702974  13.499597  7.078276
# 44  1.519614   1.519614  2.909839
# 45  2.080363   2.080363  2.080363
# 46  0.990351   0.990351  0.990351
# 47  1.122588   1.122588  1.122588
# 48  1.647810   1.647810  1.647810
#
# [25 rows x 15750 columns]

# %%
alpha = 0.05 / 2
practic_fc_normal_early = get_practic_fold_change_count(df_normal, df_early, cols, 
                                                        p_vals_normal_early, 'fdr_bh', alpha, 1.5)
practic_fc_early_cancer = get_practic_fold_change_count(df_early, df_cancer, cols, 
                                                        p_vals_early_cancer, 'fdr_bh', alpha, 1.5)

print(practic_fc_normal_early,'3-1-normal_early-fdr_bh.txt')
print(practic_fc_early_cancer,'3-2-early_cancer-fdr_bh.txt')
# Out:
# 4 3-1-normal_early-fdr_bh.txt
# 524 3-2-early_cancer-fdr_bh.txt
